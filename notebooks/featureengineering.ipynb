# %%
DIR='/Users/ravali/Desktop'
from datetime import datetime
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
ratings = pd.read_csv(DIR+'/ratings.csv', delimiter=',')
links = pd.read_csv(DIR+'/links.csv', delimiter=',')
tags = pd.read_csv(DIR+'/tags.csv', delimiter=',')
movies = pd.read_csv(DIR+'/movies.csv', delimiter=',')
display(ratings.head())
display(tags.head())
display(movies.head())
display(links.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# ...

# %%
df1=ratings.groupby('movieId').count()
df1.sort_values('rating',ascending=[False])
df1=df1.drop(['timestamp','userId'],axis=1)
display(df1)
df1.to_csv(DIR+'/featureengineering.csv')
# Out:
#          rating
# movieId
# 1           215
# 2           110
# 3            52
# 4             7
# 5            49
# 6           102
# 7            54
# 8             8
# 9            16
# 10          132
# 11           70
# 12           19
# 13            8
# 14           18
# 15           13
# 16           82
# 17           67
# 18           20
# 19           88
# 20           15
# 21           89
# 22           36
# 23           16
# 24           28
# 25           76
# 26           13
# 27            9
# 28           11
# 29           38
# 30            3
# ...         ...
# 188189        1
# 188301        3
# 188675        1
# 188751        1
# 188797        1
# 188833        1
# 189043        1
# 189111        1
# 189333        2
# 189381        1
# 189547        1
# 189713        1
# 190183        1
# 190207        1
# 190209        1
# 190213        1
# 190215        1
# 190219        1
# 190221        1
# 191005        1
# 193565        1
# 193567        1
# 193571        1
# ...

# %%
tags.groupby('movieId').count()
df2.sort_values('tag',ascending=[False])
df2.drop(['timestamp','userId'],axis=1)
df2.to_csv(DIR+'/featureengineeringtags.csv')

# %%
df5=pd.to_datetime(ratings['timestamp'], unit='s')

display(df5)
# Out:
# 0        2000-07-30 18:45:03
# 1        2000-07-30 18:20:47
# 2        2000-07-30 18:37:04
# 3        2000-07-30 19:03:35
# 4        2000-07-30 18:48:51
# 5        2000-07-30 18:40:00
# 6        2000-07-30 18:14:28
# 7        2000-07-30 18:36:16
# 8        2000-07-30 19:07:21
# 9        2000-07-30 19:08:20
# 10       2000-07-30 19:00:50
# 11       2000-07-30 18:20:08
# 12       2000-07-30 18:16:25
# 13       2000-07-30 18:19:39
# 14       2000-07-30 18:15:08
# 15       2000-07-30 18:28:00
# 16       2000-07-30 18:49:27
# 17       2000-07-30 18:38:30
# 18       2000-07-30 18:19:39
# 19       2000-07-30 18:42:43
# 20       2000-07-30 18:16:02
# 21       2000-07-30 18:43:08
# 22       2000-07-30 18:28:30
# 23       2000-07-30 18:39:23
# 24       2000-07-30 18:14:28
# 25       2000-07-30 18:31:49
# 26       2000-07-30 18:39:06
# 27       2000-07-30 18:20:08
# 28       2000-07-30 19:06:42
# 29       2000-07-30 18:19:39
#                  ...
# 100806   2016-11-19 08:13:30
# ...

# %%
new_ratings = ratings.drop('timestamp',axis=1)

df8=pd.concat([new_ratings,df5], axis=1)#ratings with time stamp converted
display(df8)
print(df8.dtypes)
# Out:
#         userId  movieId  rating           timestamp
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# 5            1       70     3.0 2000-07-30 18:40:00
# 6            1      101     5.0 2000-07-30 18:14:28
# 7            1      110     4.0 2000-07-30 18:36:16
# 8            1      151     5.0 2000-07-30 19:07:21
# 9            1      157     5.0 2000-07-30 19:08:20
# 10           1      163     5.0 2000-07-30 19:00:50
# 11           1      216     5.0 2000-07-30 18:20:08
# 12           1      223     3.0 2000-07-30 18:16:25
# 13           1      231     5.0 2000-07-30 18:19:39
# 14           1      235     4.0 2000-07-30 18:15:08
# 15           1      260     5.0 2000-07-30 18:28:00
# 16           1      296     3.0 2000-07-30 18:49:27
# ...

# %%
df8['year'] = pd.DatetimeIndex(df8['timestamp']).year

df8['month'] = pd.DatetimeIndex(df8['timestamp']).month

df8['date'] = pd.DatetimeIndex(df8['timestamp']).day

df_year=df8.groupby(['year']).count()['movieId']
df_year=df_year.to_frame()

df_year = df_year.rename(columns={'movieId': 'number of movies being rated in an year'})

df_year=df_year.sort_values('number of movies being rated in an year',ascending=False)

df_year.to_csv(DIR+'/featureengineeringdatedata.csv')

# %%
display(df_year)
# Out:
#       number of movies being rated in an year
# year
# 2000                                    10061
# 2017                                     8198
# 2007                                     7114
# 2016                                     6703
# 2015                                     6616
# 2018                                     6418
# 1996                                     6040
# 2005                                     5813
# 2012                                     4656
# 2008                                     4351
# 2009                                     4158
# 2006                                     4059
# 2003                                     4014
# 2001                                     3922
# 2002                                     3478
# 2004                                     3279
# 1999                                     2439
# 2010                                     2301
# 1997                                     1916
# ...

# %%
display(df8)
# Out:
#         userId  movieId  rating           timestamp  year  month  date
# 0            1        1     4.0 2000-07-30 18:45:03  2000      7    30
# 1            1        3     4.0 2000-07-30 18:20:47  2000      7    30
# 2            1        6     4.0 2000-07-30 18:37:04  2000      7    30
# 3            1       47     5.0 2000-07-30 19:03:35  2000      7    30
# 4            1       50     5.0 2000-07-30 18:48:51  2000      7    30
# 5            1       70     3.0 2000-07-30 18:40:00  2000      7    30
# 6            1      101     5.0 2000-07-30 18:14:28  2000      7    30
# 7            1      110     4.0 2000-07-30 18:36:16  2000      7    30
# 8            1      151     5.0 2000-07-30 19:07:21  2000      7    30
# 9            1      157     5.0 2000-07-30 19:08:20  2000      7    30
# 10           1      163     5.0 2000-07-30 19:00:50  2000      7    30
# 11           1      216     5.0 2000-07-30 18:20:08  2000      7    30
# ...

# %%
df_mergedfinal=pd.merge(tags,ratings, on=['movieId'], how='inner')
display(df_mergedfinal)
# Out:
#         userId_x  movieId               tag  timestamp_x  userId_y  rating  \
# 0              2    60756             funny   1445714994         2     5.0
# 1              2    60756             funny   1445714994        18     3.0
# 2              2    60756             funny   1445714994        62     3.5
# 3              2    60756             funny   1445714994        68     2.5
# 4              2    60756             funny   1445714994        73     4.5
# 5              2    60756             funny   1445714994       103     4.0
# 6              2    60756             funny   1445714994       111     5.0
# 7              2    60756             funny   1445714994       125     4.0
# 8              2    60756             funny   1445714994       232     3.5
# 9              2    60756             funny   1445714994       249     4.0
# 10             2    60756             funny   1445714994       274     3.0
# ...
